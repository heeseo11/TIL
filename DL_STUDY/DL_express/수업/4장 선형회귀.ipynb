# %% [markdown]
# # 경사하강법 구현

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([0.0, 1.0, 2.0])
y = np.array([3.0, 3.5, 5.5])

W = 0
b = 0

lrate = 0.01
epochs = 1000

n = float(len(X))

for i in range(epochs):
  y_pred = W*X + b
  dW = (2/n) * sum(X * (y_pred - y))
  db = (2/n) * sum(y_pred - y)
  W = W - lrate * dW
  b = b - lrate * db

print(W,b)
y_pred = W*X + b

plt.scatter(X,y)
plt.plot([min(X), max(X)], [min(y_pred), max(y_pred)], color = "red")
plt.show()
# Out:
# 1.2532418085611319 2.745502230882486

# %%
X = np.array([0.0, 1.0, 2.0])
y = np.array([3.0, 3.5, 5.5])

W = 0
b = 0

lrate = 0.01
epochs = 10

n = float(len(X))

for i in range(epochs):
  y_pred = W*X + b
  dW = (2/n) * sum(X * (y_pred - y))
  db = (2/n) * sum(y_pred - y)
  W = W - lrate * dW
  b = b - lrate * db

print(W,b)
y_pred = W*X + b

plt.scatter(X,y)
plt.plot([min(X), max(X)], [min(y_pred), max(y_pred)], color = "red")
plt.show()
# Out:
# 0.7752417245869235 0.6594717342061135

# %% [markdown]
# # 선형회귀 예제

# %%
import matplotlib.pylab as plt
from sklearn import linear_model

reg = linear_model.LinearRegression()

X = [[0],[1],[2]]
y = [3, 3.5, 5.5]

reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([1.25])

# %%
reg.intercept_
# Out:
# 2.7500000000000004

# %%
reg.score(X,y)
# Out:
# 0.8928571428571429

# %%
reg.predict([[5]])
# Out:
# array([9.])

# %%
plt.scatter(X,y, color = "black")

y_pred = reg.predict(X)
print(y_pred)

plt.plot(X,y_pred, color = "blue", linewidth = 3)
plt.show()
# Out:
# [2.75 4.   5.25]

# %% [markdown]
# # 선형회귀 실습

# %%
import matplotlib.pylab as plt
from sklearn import linear_model

reg = linear_model.LinearRegression()

X = [[174],[152],[138],[128],[186]]
y = [71,55,46,38,88]

reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([0.82021132])

# %%
reg.intercept_
# Out:
# -68.0248807089298

# %%
reg.predict(X)
# Out:
# array([74.69188821, 56.64723926, 45.16428085, 36.96216769, 84.53442399])

# %%
reg.predict([[163]])
# Out:
# array([65.66956374])

# %%
plt.scatter(X,y, color = "black")
y_pred = reg.predict(X)
plt.plot(X,y_pred, color = "blue", linewidth = 3)
plt.show()

# %% [markdown]
# # 당뇨병 예제

# %%
import matplotlib.pylab as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import datasets

# %%
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y = True)

dibetes_X_new = diabetes_X[:,np.newaxis, 2]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dibetes_X_new, diabetes_y, test_size = 0.1, random_state = 0)

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)

y_pred = regr.predict(X_test)
print(y_pred)
plt.plot(X_test, y_test,".")

plt.plot(X_test, y_pred, color = "blue", linewidth = 3)
plt.show()
# Out:
# [252.53071348 209.81076549 159.79716784 128.53866931 195.22346617
#  245.23706382 123.32891955 173.3425172  203.55906578 196.26541612
#   95.19627087 196.26541612 114.99331994 106.65772033 236.90146421
#  129.58061926  94.15432092 101.44797058  70.18947205 190.01371642
#  178.55226696 161.88106774 127.49671935 207.72686559 204.60101573
#  168.13276745 110.82552014 107.69967029 155.62936803 176.46836705
#  148.33571838 100.40602063 141.04206872 140.00011877 145.20986852
#  171.2586173  135.83231896 142.08401867 152.50351818 183.76201671
#   87.90262122 141.04206872 144.16791857 147.29376842 180.63616686]

# %% [markdown]
# # 연습문제 5번

# %%
import matplotlib.pylab as plt
from sklearn import linear_model

reg = linear_model.LinearRegression()

X = [[2015],[2016],[2017],[2018],[2019]]
y = [12,19,28,37,46]

reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([8.6])

# %%
reg.intercept_
# Out:
# -17317.800000000007

# %%
reg.predict(X)
# Out:
# array([11.2, 19.8, 28.4, 37. , 45.6])

# %%
reg.predict([[2020]])
# Out:
# array([54.2])

# %% [markdown]
# ##### (a) y = 8.6 X - 17317.8
# ##### (b) 2020년 매출 : 54.2로 예측

# %% [markdown]
# # 연습문제 6번

# %%
reg = linear_model.LinearRegression()

X = [[1930],[1940],[1950],[1960],[1970],[1980],[1990],[2010],[2019]]
y = [59,62,70,69,71,74,75,76,78]
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([0.19482338])

# %%
reg.intercept_
# Out:
# -313.76889855245133

# %%
reg.predict(X)
# Out:
# array([62.24021564, 64.1884494 , 66.13668315, 68.0849169 , 70.03315065,
#        71.9813844 , 73.92961816, 77.82608566, 79.57949604])

# %%
reg.predict([[1962]])
# Out:
# array([68.47456365])

# %% [markdown]
# ##### y = 0.19 X - 313.7
# ##### 1962년 기대수명 : 68.47로 예측

# %% [markdown]
# # 연습문제 7번

# %%
X = [[30],[35],[20],[15],[3]]
y = [90,95,70,40,10]

# %%
regr = linear_model.LinearRegression()
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
# X와 y 사이의 관계를 설명하는 직선
y_pred = regr.predict(X)
print(y_pred)
plt.plot(X, y,".")

plt.plot(X, y_pred, color = "blue", linewidth = 3)
plt.show()
# Out:
# [ 87.14061519 101.04519774  59.33145009  45.42686755  12.05586943]
